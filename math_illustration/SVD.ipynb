# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os 

A = imread('dog.jpg')

# %%
X = np.mean(A,-1)

# %%
X.shape
# Out:
# (183, 194)

# %%
img = plt.imshow(256-X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U,S,VT = np.linalg.svd(X,full_matrices=False)

S = np.diag(S)

# %%
S
# Out:
# array([[3.28032581e+04, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 5.87623349e+03, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 3.27658368e+03, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.71948720e-01, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 1.51795037e-01, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.03447660e-01]])
